# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress

# %%
# Read in csv file
fire_data = 'Resources/California_Fire_Incidents.csv'
fire_data_df = pd.read_csv(fire_data)
fire_data_df.head()
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# ...

# %%
# Clean data
fire_ca = fire_data_df[columns==[
    'AcresBurned', 'AdminUnit', 'AirTankers', 'ArchiveYear', 'CalFireIncident', 'Counties', 'CountyIds'
]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cd051154d8d3> in <module>
#       1 # Clean data
# ----> 2 fire_ca = fire_data_df[columns==[
#       3     'AcresBurned', 'AdminUnit', 'AirTankers', 'ArchiveYear', 'CalFireIncident', 'Counties', 'CountyIds'
#       4 ]]
#
# NameError: name 'columns' is not defined
