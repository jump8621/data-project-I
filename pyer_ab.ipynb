# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress

# %%
# Read in csv file
fire_data = 'Resources/California_Fire_Incidents.csv'
fire_data_df = pd.read_csv(fire_data)
fire_data_df.head()
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# 4      /incidents/2013/5/2/springs-fire/
#
#                                   ConditionStatement ControlStatement  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Acreage has been reduced based upon more accur...              NaN
#
#       Counties  ...  Started     Time.1     Status  StructuresDamaged  \
# 0     Tuolumne  ...  8/17/13  15:25:00Z  Finalized                NaN
# 1  Los Angeles  ...  5/30/13  15:28:00Z  Finalized                NaN
# 2    Riverside  ...  7/15/13  13:43:00Z  Finalized                NaN
# 3       Placer  ...  8/10/13  16:30:00Z  Finalized                NaN
# 4      Ventura  ...   5/2/13  07:01:00Z  Finalized                6.0
#
#   StructuresDestroyed StructuresEvacuated  StructuresThreatened  \
# 0                 NaN                 NaN                   NaN
# 1                 NaN                 NaN                   NaN
# 2                 NaN                 NaN                   NaN
# 3                 NaN                 NaN                   NaN
# 4                10.0                 NaN                   NaN
#
#                                UniqueId               Updated  WaterTenders
# 0  5fb18d4d-213f-4d83-a179-daaf11939e78  2013-09-06T18:30:00Z           NaN
# 1  bf37805e-1cc2-4208-9972-753e47874c87  2013-06-08T18:30:00Z           NaN
# 2  a3149fec-4d48-427c-8b2c-59e8b79d59db  2013-07-30T18:00:00Z           NaN
# 3  8213f5c7-34fa-403b-a4bc-da2ace6e6625  2013-08-30T08:00:00Z           NaN
# 4  46731fb8-3350-4920-bdf7-910ac0eb715c  2013-05-11T06:30:00Z          11.0
#
# [5 rows x 43 columns]

# %%
# Clean data
ca_fire_df = fire_data_df.drop(columns=[
    "Active", 
    "CanonicalUrl", 
    "ConditionStatement", 
    "FuelType", 
    "Location", 
    "ControlStatement", 
    "CalFireIncident", 
    "AdminUnit", 
    "PercentContained", 
    "Time.1", 
    "Time", 
    "Status", 
    "SearchDescription", 
    "SearchKeywords", 
    "Public", 
    "Updated"], inplace=False)

# Store clean data in csv file
ca_fire_df.to_csv('output_data/california_fire_cleaned.csv', index=False, header=True)

ca_fire_df.head()
# Out:
#    AcresBurned  AirTankers  ArchiveYear     Counties CountyIds  CrewsInvolved  \
# 0     257314.0         NaN         2013     Tuolumne        55            NaN
# 1      30274.0         NaN         2013  Los Angeles        19            NaN
# 2      27531.0         NaN         2013    Riverside        33            NaN
# 3      27440.0         NaN         2013       Placer        31            NaN
# 4      24251.0         NaN         2013      Ventura        56           47.0
#
#    Dozers  Engines Extinguished  Days Burned  ...  MajorIncident  \
# 0     NaN      NaN       9/6/13           20  ...          False
# 1     NaN      NaN       6/8/13            9  ...          False
# 2     NaN      NaN      7/30/13           15  ...          False
# 3     NaN      NaN      8/30/13           20  ...          False
# 4     8.0    117.0      5/11/13            9  ...           True
#
#               Name  PersonnelInvolved  Started  StructuresDamaged  \
# 0         Rim Fire                NaN  8/17/13                NaN
# 1  Powerhouse Fire                NaN  5/30/13                NaN
# 2    Mountain Fire                NaN  7/15/13                NaN
# 3    American Fire                NaN  8/10/13                NaN
# 4     Springs Fire             2167.0   5/2/13                6.0
#
#    StructuresDestroyed  StructuresEvacuated  StructuresThreatened  \
# 0                  NaN                  NaN                   NaN
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
# 3                  NaN                  NaN                   NaN
# 4                 10.0                  NaN                   NaN
#
#                                UniqueId  WaterTenders
# 0  5fb18d4d-213f-4d83-a179-daaf11939e78           NaN
# 1  bf37805e-1cc2-4208-9972-753e47874c87           NaN
# 2  a3149fec-4d48-427c-8b2c-59e8b79d59db           NaN
# 3  8213f5c7-34fa-403b-a4bc-da2ace6e6625           NaN
# 4  46731fb8-3350-4920-bdf7-910ac0eb715c          11.0
#
# [5 rows x 27 columns]
